# %% [markdown]
# # Pipelines

# %% [markdown]
# #### Attribute Rulers

# %%
import spacy
#make a blank spacy pipeline

# %%
nlp = spacy.blank("en")

# %%
nlp.add_pipe("sentencizer") #esto te permitirá crear un pipeline que contenga una secuencia de dos pipes distintas

# %% [markdown]
# A veces necesitas dividir un text en frases individuales
#
# Cogemos un massive corpus de internet (shakespeare corpus) y calculamos con el sentencizer el numero de frases (94133), y tardó en calcularlo 7.54 segundos
#
# Usando el modelo small toma 47 minutos en dividir todas las frases y extraerlas, pero extrae 112074 frases.
#
# Esto es proque el sm tiene otro montón de pipes que están intentando hacer otro montón de cosas (a bunch of other things)
#
# Si tu solo necesitas hacer una tarea, es buena idea
# * Activar solo un pipe o
# * Crear un modelo blank (blank model) y añadir la pipe o las pipes que necesitas
#
# Ejemplo, necesitas tokenizar un lote de frases.
#
# El sm aunque tarde mucho más es mucho más preciso en como encuentra límites entre frases, por eso detecta más.
#
# El sentencizer no tiene o no conoce datos extra. Con modelos más grande , mejores resultados

# %%
nlp.analyze_pipes()
# Out:
# {'summary': {'sentencizer': {'assigns': ['token.is_sent_start', 'doc.sents'],
#    'requires': [],
#    'scores': ['sents_f', 'sents_p', 'sents_r'],
#    'retokenizes': False}},
#  'problems': {'sentencizer': []},
#  'attrs': {'token.is_sent_start': {'assigns': ['sentencizer'], 'requires': []},
#   'doc.sents': {'assigns': ['sentencizer'], 'requires': []}}}

# %%
nlp2 = spacy.load('en_core_web_sm')

# %%
nlp2.analyze_pipes() #Mucho más complejo
# Out:
# {'summary': {'tok2vec': {'assigns': ['doc.tensor'],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'tagger': {'assigns': ['token.tag'],
#    'requires': [],
#    'scores': ['tag_acc',
#     'pos_acc',
#     'tag_micro_p',
#     'tag_micro_r',
#     'tag_micro_f'],
#    'retokenizes': False},
#   'parser': {'assigns': ['token.dep',
#     'token.head',
#     'token.is_sent_start',
#     'doc.sents'],
#    'requires': [],
#    'scores': ['dep_uas',
#     'dep_las',
#     'dep_las_per_type',
#     'sents_p',
#     'sents_r',
#     'sents_f'],
#    'retokenizes': False},
#   'attribute_ruler': {'assigns': [],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'lemmatizer': {'assigns': ['token.lemma'],
#    'requires': [],
#    'scores': ['lemma_acc'],
#    'retokenizes': False},
#   'ner': {'assigns': ['doc.ents', 'token.ent_iob', 'token.ent_type'],
#    'requires': [],
#    'scores': ['ents_f', 'ents_p', 'ents_r', 'ents_per_type'],
# ...
